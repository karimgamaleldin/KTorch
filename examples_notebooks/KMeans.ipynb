# %% [markdown]
# # KMeans Example Notebook
#
# This notebook tests the implementation of the KMeans clustering algorithm implemented in KTorch

# %%
# imports
# %cd ..
from algorithms.cluster.KMeans import KMeans
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(1)
# Out:
# /home/karimgamaleldin/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /home/karimgamaleldin/Projects/KTorch

# %%
# Getting the data
from sklearn.datasets import make_blobs

X, _ = make_blobs(n_samples=300, centers=3, n_features=2, random_state=42)

# %%
# Plotting the data
plt.scatter(X[:, 0], X[:, 1])
plt.title("Blobs")
plt.show()

# %%
# Initiate and fit the kmeans 
kmeans = KMeans(n_clusters=3, max_iter=400, init='random')
kmeans.fit(X)

# %%
# Plotting the data with the clusters
labels = kmeans.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.scatter(kmeans.centroids[:, 0], kmeans.centroids[:, 1], c='red', marker='x')
plt.title("Blobs with clusters")
plt.show()

# %% [markdown]
# A problem appears because of the random initialization of

# %%
# Initiate and fit the kmeans with kmeans++
kmeans = KMeans(n_clusters=3, max_iter=400, init='kmeans++')
kmeans.fit(X)

# %%
# Plotting the data with the clusters
labels = kmeans.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.scatter(kmeans.centroids[:, 0], kmeans.centroids[:, 1], c='red', marker='x')
plt.title("Blobs with clusters")
plt.show()

# %% [markdown]
# `KMeans++` fixed this problem

# %% [markdown]
# ### Testing the rest of the methods

# %%
# test score function
kmeans.score(X)
# Out:
# np.float64(566.8595511244131)

# %%
# test predict function
kmeans.predict(X)
# Out:
# array([1., 1., 2., 0., 1., 0., 2., 0., 2., 2., 2., 0., 2., 2., 1., 2., 1.,
#        0., 2., 2., 2., 2., 0., 1., 2., 1., 1., 0., 0., 2., 2., 2., 1., 2.,
#        1., 2., 1., 0., 1., 0., 0., 2., 1., 0., 2., 2., 1., 0., 1., 0., 0.,
#        1., 1., 2., 1., 0., 1., 2., 0., 2., 1., 0., 0., 1., 1., 0., 0., 1.,
#        1., 2., 0., 1., 1., 2., 2., 1., 1., 0., 2., 0., 2., 2., 1., 2., 0.,
#        1., 1., 2., 0., 2., 1., 2., 1., 2., 2., 1., 1., 2., 1., 1., 0., 2.,
#        0., 2., 2., 2., 2., 2., 0., 1., 0., 2., 2., 2., 2., 0., 1., 0., 1.,
#        0., 0., 0., 2., 1., 1., 1., 1., 2., 1., 1., 2., 2., 2., 2., 2., 0.,
#        0., 1., 2., 1., 2., 2., 1., 2., 0., 0., 0., 2., 0., 2., 2., 1., 0.,
#        1., 2., 0., 0., 1., 1., 2., 2., 1., 1., 1., 2., 1., 0., 2., 2., 2.,
#        2., 2., 0., 2., 0., 0., 0., 2., 0., 0., 1., 2., 1., 0., 0., 1., 0.,
#        2., 0., 0., 1., 1., 0., 1., 0., 0., 0., 0., 2., 1., 2., 2., 0., 0.,
# ...

# %%
# test fit_predict function
kmeans = KMeans(n_clusters=3, max_iter=400, init='kmeans++')
kmeans.fit_predict(X)
# Out:
# array([1., 1., 0., 2., 1., 2., 0., 2., 0., 0., 0., 2., 0., 0., 1., 0., 1.,
#        2., 0., 0., 0., 0., 2., 1., 0., 1., 1., 2., 2., 0., 0., 0., 1., 0.,
#        1., 0., 1., 2., 1., 2., 2., 0., 1., 2., 0., 0., 1., 2., 1., 2., 2.,
#        1., 1., 0., 1., 2., 1., 0., 2., 0., 1., 2., 2., 1., 1., 2., 2., 1.,
#        1., 0., 2., 1., 1., 0., 0., 1., 1., 2., 0., 2., 0., 0., 1., 0., 2.,
#        1., 1., 0., 2., 0., 1., 0., 1., 0., 0., 1., 1., 0., 1., 1., 2., 0.,
#        2., 0., 0., 0., 0., 0., 2., 1., 2., 0., 0., 0., 0., 2., 1., 2., 1.,
#        2., 2., 2., 0., 1., 1., 1., 1., 0., 1., 1., 0., 0., 0., 0., 0., 2.,
#        2., 1., 0., 1., 0., 0., 1., 0., 2., 2., 2., 0., 2., 0., 0., 1., 2.,
#        1., 0., 2., 2., 1., 1., 0., 0., 1., 1., 1., 0., 1., 2., 0., 0., 0.,
#        0., 0., 2., 0., 2., 2., 2., 0., 2., 2., 1., 0., 1., 2., 2., 1., 2.,
#        0., 2., 2., 1., 1., 2., 1., 2., 2., 2., 2., 0., 1., 0., 0., 2., 2.,
# ...

# %%
# test fit_transform function
kmeans = KMeans(n_clusters=3, max_iter=400, init='kmeans++')
kmeans.fit_transform(X)
# Out:
# array([[17.42111457, 15.522625  ,  0.87384313],
#        [17.08911972, 15.55503779,  0.90100321],
#        [ 1.5680663 ,  8.65069655, 15.66471908],
#        [ 9.24334253,  1.10996953, 15.13105904],
#        [18.06045041, 16.87347954,  2.22581816],
#        [10.88058987,  0.77595426, 15.18849291],
#        [ 0.46378589, 10.23562638, 17.00308591],
#        [10.83305662,  0.67441605, 14.59225939],
#        [ 0.41511947, 10.31131172, 16.28537982],
#        [ 1.23795376, 11.40356884, 16.95632647],
#        [ 1.88453686, 11.83961524, 18.24492709],
#        [10.88521086,  0.77187016, 14.47239912],
#        [ 2.0166206 ,  8.66651771, 14.7679082 ],
#        [ 1.36747356, 10.88735011, 15.85622515],
#        [17.1258718 , 15.44919326,  0.75147291],
#        [ 0.67934907, 10.3877222 , 16.09521993],
#        [16.92742254, 15.9332251 ,  1.63039491],
#        [ 8.65620514,  2.13756858, 13.18442735],
#        [ 0.96503394, 10.7150658 , 17.5463038 ],
#        [ 2.27508944, 11.3584255 , 18.85328996],
# ...
